# %% [markdown]
# <a href="https://colab.research.google.com/github/monsterhunters/sub/blob/dev/Hardsub2Softsub_V3_3_SU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <img src='https://fiverr-res.cloudinary.com/images/t_main1,q_auto,f_auto,q_auto,f_auto/gigs/201283509/original/bded753530fef9a172ef7c932905e2496cd2072c/make-srt-and-ass-subtitle-file-from-any-hardsub-video.png' height="50" alt="iceWM" /> ___Hardsub2Softsub V 3.3 SU___

# %%
#@title ← Check Your Notebook Info (Optional)
#@markdown - Your CPU total threads should be <b>40</b> in <b>TPU Mode</b>, otherwise process may slow.
from psutil import *
#!nvidia-smi
# !python -V
#!cat /proc/version
# !lscpu |grep 'Model name'
#!cat /proc/cpuinfo
# !lscpu | grep 'Thread(s) per core'
# !lscpu | grep "L3 cache"
# !lscpu | grep 'Socket(s):'
# !lscpu | grep 'Core(s) per socket:'
# !lscpu | grep "MHz"
print("Total No of Thread(s) " + str(cpu_count()))

# !cat /proc/meminfo | grep 'MemAvailable'
virtual_memory()
# !df -h
# !df -h / | awk '{print $4}'

# %%
#@title ← Install Modules
#@markdown - Need only for one time, you can skip this step for another operation
#@markdown - CPU Power <code>(Default : Medium, Low : Recommend for Non TPU Mode, Very_High : Recommend for TPU Mode with 40 threads)</code>
cpu_power = "Medium" #@param ["Low", "Medium", "High", "Very_High (Only for TPU with 40 threads)", "Extreme"]

import os, urllib.request, random
from pathlib import Path
from IPython.display import clear_output

HOME = os.path.expanduser("~")
pathDoneCMD = f'{HOME}/doneCMD.sh'
if not os.path.exists(f"{HOME}/.ipython/ttmg.py"):
    hCode = "https://raw.githubusercontent.com/monsterhunters/sub/dev/ttmg.py" 
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ttmg.py")

from ttmg import (
    loadingAn,
    textAn,
)

loadingAn(name="lds")
textAn("Installing Dependencies...", ty='twg')
version = "3.3.0.2100809"
os.chdir('/content')
ocr = "ocr"
if not Path(ocr).exists():
 os.mkdir(ocr)
#os.system('!git clone https://totalleecher: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@github.com/totalleecher/ocr.git')
os.chdir(ocr)
os.system('wget https://raw.githubusercontent.com/monsterhunters/sub/dev/ver.json')
os.system('pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib')
f = open("ver.json", "r")
ver = f.readline()
#print(f.read()) 
#CPU Power
if cpu_power == "Low":
 cpu = 5
elif cpu_power == "Medium":
 cpu = 10
elif cpu_power == "High":
 cpu = 15
elif cpu_power == "Extreme":
 cpu = 30
else:
 cpu = 20

with open('cpu.txt','w') as f:
  f.write(str(cpu))

if ver == version:
  os.system('pip install srtmerge')
  os.system('pip install cloud-downloader-equitania')
  os.system('pip install pydrive')
  os.system('wget https://raw.githubusercontent.com/monsterhunters/sub/dev/main.py')
  os.system('wget https://raw.githubusercontent.com/monsterhunters/sub/dev/main2.py')
  os.system('wget https://raw.githubusercontent.com/monsterhunters/sub/dev/sa.zip')
  os.system('unzip sa.zip')
  os.system('rm sa.zip')
  current_file_name = random.choice(os.listdir("accounts"))
  os.rename('accounts/'+str(current_file_name), 'sa-account.json')
  os.system('rm -R accounts')
  os.remove('ver.json')
  clear_output()
  print("Install Finished")
  print("If you want steal-version of my code, get that version on thief's repo@ https://github.com/premiumcoder/ss")
else:
  os.remove('ver.json')
  clear_output()
  print("Please get latest version")



#Codemaster V3.2
# Out:
# Install Finished
# If you want steal-version of my code, get that version on thief's repo@ https://github.com/premiumcoder/ss

# %%
#@title ← Upload Images from Video Sub Finder for OCR
#@markdown - Please Upload RAR file contaning Images (RGB Images)
#@markdown - Gdrive Link format must be format as below (Otherwise downloaded file will not work)
#@markdown - <code>https://drive.google.com/u/6/uc?id=1QGMGef-QHuJAXsOtPyKwDz1WbS2ndGCl&export=download</code>


import gdown, os
Upload_from = "Gdrive3" #@param ["Gdrive","Gdrive2","Gdrive3","PC", "Direct Link"]
url = "" #@param {type:"string"}
#@markdown - Gdrivefile_id only vaild for Gdrive3
gdrivefile_id = "1lcpQkGAT55xJcgrdyHQ1gbx1hbcDQ5xQ" #@param {type:"string"}
if Upload_from == "Gdrive":
  output = "RGBimages.rar"
  gdown.download(url, output, quiet=False)

elif Upload_from == "Gdrive2":
  # !cloud-download --link "$url" --filename RGBimages.rar
  print("Downloaded [2560=ERR]")

elif Upload_from == "Gdrive3":
  from pydrive.auth import GoogleAuth
  from pydrive.drive import GoogleDrive
  from google.colab import auth
  from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
  auth.authenticate_user()
  gauth = GoogleAuth()
  gauth.credentials = GoogleCredentials.get_application_default()
  drive = GoogleDrive(gauth)
  downloaded = drive.CreateFile({'id': gdrivefile_id})
  downloaded.GetContentFile('RGBimages.rar')

elif Upload_from == "PC":
 from google.colab import files
 uploaded = files.upload()

else:
 os.system('pip install wget')
 import wget
 filename = wget.download(url)
 print(filename)
 print("Downloaded")
 
os.system('cp *.rar backup.bak')

#Codemaster V2.1 VSF  

#@title ← Extract RAR

import fnmatch,os

up = "./up"
down = "./down"
from pathlib import Path
if not Path('up').exists():
  os.mkdir(up)
if not Path('down').exists():
  os.mkdir(down)

os.system("unrar x *.rar up")
os.system("unrar x *.rar down")
# Out:
# 0

# %%
#@title ← Select your sample photo to crop/enhance 
#@markdown - Please set <b>line between upper and lower </b>subtitle. To adjust fine tuning, please use keyboard arrow.
#@markdown - Enhancement (optional) for Better OCR reading.(<i>Uncheck if original movie is very dark and subtitle color is unclear</i>)
Do_Not_Crop = False  # @param {type:"boolean"}
Enhancement = True  # @param {type:"boolean"}
#@markdown - Enhancement_value <code>(Original : B,S,C = 1) (Optimal : B = 0.5, S = 1, C = 1) (Anime : B = 0.2, S = 5, C = 5) (GC : B = 0.3)[*Wrong Value May Cause OCR ERR*]</code>
Brightness_value = 0.5 #@param {type:"slider", min:0.2, max:1, step:0.1}
Sharpness_value = 1 #@param {type:"slider", min:1, max:5, step:0.1}
Color_value = 1 #@param {type:"slider", min:0, max:5, step:0.1}

if Enhancement:
  fb = Brightness_value
  fs = Sharpness_value
  fc = Color_value

else:
  fb = 1
  fs = 1
  fc = 1




#os.makedirs("./temp", exist_ok=True)
import os
#if not os.path.exists(path):
 #   os.makedirs(path)

# %matplotlib inline
from PIL import Image, ImageEnhance
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np
import re
from IPython.display import display, clear_output
from ipywidgets import widgets
from os import listdir
from os.path import isfile, join
from IPython.display import HTML
from base64 import b64encode


mypath = 'up/'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
if Do_Not_Crop:
 with open('config.txt','w') as f:
   f.write("no_crop")
 

 if Enhancement: 
  f = r'up'
  for file in os.listdir(f):
   f_img = f+"/"+file
   img = Image.open(f_img)
   enhancer = ImageEnhance.Brightness(img)
   im_output = enhancer.enhance(fb)
   enhancer = ImageEnhance.Sharpness(im_output)
   im_output = enhancer.enhance(fs)
   enhancer = ImageEnhance.Color(im_output)
   im_output = enhancer.enhance(fc)
   im_output.save(f_img)    
  print('Image_Enhanced (Warning - You have selected No Crop Option, thus you only need to run upper line later)')
 else: 
   print('No_Image_Enhanced (Warning - You have selected No Crop Option, thus you only need to run upper line later)')

else:
 with open('config.txt','w') as f:
   f.write("crop")
 if len(onlyfiles)>0:
  filename_ch = widgets.Dropdown(
      options=onlyfiles,
      description='Choose file:',
  )
  butt = widgets.Button(description='Select')
  def on_butt_clicked(b):
      print(filename_ch.value)
      
      source = str(mypath)+filename_ch.value
      im = Image.open(source)
      #display(im)
      #f = open("./temp/selectedvideo.txt","w") 
      #f.write(filename_ch.value)
      #f.close() 
      w, h = im.size
      print("Image Resolution "+str(w)+"x"+str(h))

      def f(crop_line):
          plt.figure(figsize = (20,6))
          image = plt.imread(source)
          plt.imshow(image)
          x = np.linspace(crop_line, crop_line, num=w)
          plt.plot(x)
          #plt.ylim(0, 2000)
          plt.show()
      interactive_plot = interactive(f, crop_line=(1, h))
      output = interactive_plot.children[-1]
      output.layout.height = '{h}px'
      interactive_plot   

      def on_button_clicked(b):
           with output:
        
            s = str(interactive_plot)
            pattern = "value=(.*?),"
            substring = re.search(pattern,s).group(1)
            z = int(substring)
            #print(substring)
            print('Please wait.. Images are being cropped')
            f = r'up'
            for file in os.listdir(f):
              f_img = f+"/"+file
              img = Image.open(f_img)
              img = img.crop((0,0,w,z))
              enhancer = ImageEnhance.Brightness(img)
              im_output = enhancer.enhance(fb)
              enhancer = ImageEnhance.Sharpness(im_output)
              im_output = enhancer.enhance(fs)
              enhancer = ImageEnhance.Color(im_output)
              im_output = enhancer.enhance(fc)
              im_output.save(f_img)
            g = r'down'
            for file in os.listdir(g):
              g_img = g+"/"+file
              img = Image.open(g_img)
              img = img.crop((0,z,w,h))
              enhancer = ImageEnhance.Brightness(img)
              im_output = enhancer.enhance(fb)
              enhancer = ImageEnhance.Sharpness(im_output)
              im_output = enhancer.enhance(fs)
              enhancer = ImageEnhance.Color(im_output)
              im_output = enhancer.enhance(fc)
              im_output.save(g_img)
            #clear_output()
            print('Image_Cropped')
            if Enhancement:
              print('Image_Enhanced')
              
            #im1 = im.crop((0, 0, w, z))
            #im2 = im.crop((0, z, w, h))
            #display(im1)
            #display(im2)

      button = widgets.Button(description="Crop")
      output = widgets.Output()
      display(interactive_plot, button, output)
      button.on_click(on_button_clicked)
      
  butt.on_click(on_butt_clicked)
  # display
  display(widgets.VBox([filename_ch,butt]))
 else:
  print('Upload photo at first')
  
#Codemaster V3.2
# Out:
# ...
# 1_08_41_720__1_08_43_119.jpeg
# Image Resolution 850x480
# interactive(children=(IntSlider(value=240, description='crop_line', max=480, min=1), Output(layout=Layout(heig…
# Button(description='Crop', style=ButtonStyle())
# Output()

# %%
#@markdown <h3>←  Extract files </h3>
from shutil import rmtree
import fnmatch,os
#temp = "./temp"
cpu = int(open("cpu.txt","r").readline())
crop = str(open("config.txt","r").readline())

#from pathlib import Path
#if not Path('temp').exists():
#  os.mkdir(temp)
#os.system("unrar x *.rar temp")
#Counting files
path, dirs, files = next(os.walk("up"))
file_count = len(files)

#Additional Speed Up
float_num = file_count/cpu
x = round(float_num)
i = x + 1

#Reading Data
ext = ".jpg"
counter = 0
dir_counter = 0
os.mkdir(f"images{dir_counter}")
current_dir = f"images{dir_counter}"
for file in os.listdir(up):
    if counter % i == 0:
        dir_counter +=1
        os.mkdir(f"images{dir_counter}")
        current_dir = f"images{dir_counter}"
    if file.endswith(tuple(ext)):
      os.rename(f"{up}/{file}",f"{current_dir}/{file}")
      counter += 1
# write counter

with open('counter.txt','w') as f:
  f.write(str(counter))

#clean
os.rmdir(up)

if crop == "no_crop":
 print(f"Total {counter} {ext} files")
 rmtree(down)
else:
 print(f"Total {counter} {ext} files (Upper Line)")


#--------------------

#temp = "./temp"

#from pathlib import Path
#if not Path('temp').exists():
#  os.mkdir(temp)
#os.system("unrar x *.rar temp")
#Counting files
 path, dirs, files = next(os.walk("down"))
 file_count = len(files)

#Additional Speed Up
 float_num = file_count/cpu
 x = round(float_num)
 i = x + 1



#Reading Data
 ext = ".jpg"
 counter = 0
 dir_counter = int(cpu)+1
 os.mkdir(f"images{dir_counter}")
 current_dir = f"images{dir_counter}"
 for file in os.listdir(down):
    if counter % i == 0:
        dir_counter +=1
        os.mkdir(f"images{dir_counter}")
        current_dir = f"images{dir_counter}"
    if file.endswith(tuple(ext)):
      os.rename(f"{down}/{file}",f"{current_dir}/{file}")
      counter += 1
# write counter
 print(f"Total {counter} {ext} files (Lower Line)")
 with open('counter.txt','w') as f:
  f.write(str(counter))

#clean
 os.rmdir(down)
# Out:
# Total 608 .jpg files (Upper Line)
# Total 608 .jpg files (Lower Line)

# %%
 #@title ← RUN (Upper Line)/Single Line OCR Operation
#@markdown - If progress freeze/hang, click this button again to resume OCR process.

import multiprocessing
cpu = int(open("cpu.txt","r").readline())

def mymaina(mydir):
  # !python main.py {mydir}

for i in range(1,int(cpu)+1):
    myimages = f"images{i}"
    p = multiprocessing.Process(target=mymaina, args=(myimages,))
    p.start()
    
print("Done")
#Codemaster V2.2 VSF
# Out:
# Done

# %%
 #@title ← RUN (Lower Line)
#@markdown - If progress freeze/hang, click this button again to resume OCR process.

import multiprocessing
cpu = int(open("cpu.txt","r").readline())
crop = str(open("config.txt","r").readline())
if crop == "no_crop":
  print("You don't need to run this cell for single line operation. Skip to another cell.")
else:
  def mymainb(mydir):
   # !python main2.py {mydir}

  for i in range(int(cpu)+2,int(cpu)*2+2):
    myimages = f"images{i}"
    p = multiprocessing.Process(target=mymainb, args=(myimages,))
    p.start()
    
  print("Done")
#Codemaster V2.2 VSF
# Out:
# Done

# %%
#@title ← Check Progress
#@markdown - If progress freeze/Hang, please re-click <b>"Run"</b> button, <u>wait a minute</u> and re-check progress.

import os
from IPython.display import HTML, display
import time

Counter = int(open("counter.txt","r").readline())
crop = str(open("config.txt","r").readline())

if os.path.isdir('texts'):
 file_count = len(os.listdir("texts"))
 if crop == "no_crop":
  print("Total File Done ")
  print(str(file_count)+" of "+str(Counter))
 else:
  print("Total File Done (Upper Line)")
  print(str(file_count)+" of "+str(Counter))
 if file_count == Counter:
  if crop == "no_crop":
   print("OCR Completed")
   os.rename("up.srt","subtitle_output.srt")
   from google.colab import files
   files.download('subtitle_output.srt')
   
  else:
   print("Upper Line OCR Completed")
  #!mv subtitle_output.srt up.srt

else:
 print('Initializing... Please be patient')


#  from google.colab import files
#  files.download('subtitle_output.srt') 

#while file_count != Counter:


def progress(value, max=100):
    return HTML("""
        <progress
            value='{value}'
            max='{max}',
            style='width: 100%'
        >
            {value}
        </progress>
    """.format(value=file_count, max=Counter))

out = display(progress(0, 100), display_id=True)

#--------------------------

if os.path.isdir('texts2'):
 file_count = len(os.listdir("texts2"))
 if crop != "no_crop":
   print("Total File Done (Lower Line)")
   print(str(file_count)+" of "+str(Counter))
   if file_count == Counter:
    if crop != "no_crop":
     print("Lower Line OCR Completed")
  #!mv subtitle_output.srt down.srt

else:
 if crop != "no_crop":
  print('Initializing... Please be patient')



#  from google.colab import files
#  files.download('subtitle_output.srt') 

#while file_count != Counter:


def progress(value, max=100):
    return HTML("""
        <progress
            value='{value}'
            max='{max}',
            style='width: 100%'
        >
            {value}
        </progress>
    """.format(value=file_count, max=Counter))
if crop != "no_crop":
 out = display(progress(0, 100), display_id=True)
# Out:
# Total File Done (Upper Line)
# 155 of 608
#         <progress
#             value='155'
#             max='608',
#             style='width: 100%'
#         >
#             155
#         </progress>
# Total File Done (Lower Line)
# 136 of 608
#         <progress
#             value='136'
#             max='608',
#             style='width: 100%'
#         >
#             136
#         </progress>

# %%
#@title ← Download Complete Subtitle
#@markdown - You don't need to run this cell for single line OCR operation.

# !srtmerge up.srt down.srt subtitle_output.srt
from google.colab import files
files.download('subtitle_output.srt')

# %%
#@title ← Clear All data for another operation
#@markdown - After that you can start from <u><b>step-2 (Upload RAR)</u></b> for another operation
#@markdown - Recommend to factory reset runtime after one operation.
Clear_backup_file = False  # @param {type:"boolean"}
# !rm *.srt
# !rm *.rar
# !rm *.txt
# !rm -R -- */
#!mkdir raw_texts
#!mkdir texts

if Clear_backup_file == True:
  # !rm *.bak
# !kill $(ps aux | grep 'main.py' | awk '{print $2}')
# !kill $(ps aux | grep 'main2.py' | awk '{print $2}')

#Codemaster V2.2 VSF

# %% [markdown]
# ### <center><h3>Copyright © 2021. All right reserved.</h3></b></div><h5>Code by <b>Codemaster@BSSG & SengKyaut</b></h5></center></h5>
# <font size=4 color="red"><center><i>(Again! Do not steal my work)</i></center></font>
